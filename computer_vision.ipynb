# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.6/112.6 GB disk)

# %%
# This runs the AI on your video
# !yolo track model=yolov8n.pt source=football.mp4 save=True
# Out:
# ...
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 2 packages in 157ms
# Prepared 1 package in 54ms
# Installed 1 package in 2ms
#  + lap==0.5.12
#
# requirements: AutoUpdate success ✅ 0.6s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# video 1/1 (frame 1/843) /content/football.mp4: 640x384 11 persons, 109.7ms
# video 1/1 (frame 2/843) /content/football.mp4: 640x384 11 persons, 9.4ms
# video 1/1 (frame 3/843) /content/football.mp4: 640x384 10 persons, 9.0ms
# video 1/1 (frame 4/843) /content/football.mp4: 640x384 11 persons, 9.1ms
# video 1/1 (frame 5/843) /content/football.mp4: 640x384 10 persons, 8.9ms
# video 1/1 (frame 6/843) /content/football.mp4: 640x384 10 persons, 9.1ms
# ...

# %%
from IPython.display import Video
import glob
# Find the latest video
latest_video = glob.glob('runs/detect/track*/football.mp4')[-1]
Video(latest_video, embed=True, width=600)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3700052698.py in <cell line: 0>()
#       2 import glob
#       3 # Find the latest video
# ----> 4 latest_video = glob.glob('runs/detect/track*/football.mp4')[-1]
#       5 Video(latest_video, embed=True, width=600)
#
# IndexError: list index out of range

# %%
import glob
from IPython.display import Video

# This searches for ANY .mp4 file in the output folder
try:
    # Look for any mp4 file inside runs/detect/track...
    video_files = glob.glob('runs/detect/track*/*.mp4')

    # Get the last one (most recent run)
    latest_video = video_files[-1]

    print(f"Found video: {latest_video}")
    display(Video(latest_video, embed=True, width=600))

except IndexError:
    print("❌ No video found. This means the YOLO tracking command didn't finish.")
    print("Check: Did you upload the video and rename it correctly in the sidebar?")
# Out:
# ❌ No video found. This means the YOLO tracking command didn't finish.
# Check: Did you upload the video and rename it correctly in the sidebar?

# %%
# !yolo track model=yolov8n.pt source=football.mp4 save=True
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# video 1/1 (frame 1/843) /content/football.mp4: 640x384 11 persons, 48.2ms
# video 1/1 (frame 2/843) /content/football.mp4: 640x384 11 persons, 10.1ms
# video 1/1 (frame 3/843) /content/football.mp4: 640x384 10 persons, 8.7ms
# video 1/1 (frame 4/843) /content/football.mp4: 640x384 11 persons, 8.8ms
# video 1/1 (frame 5/843) /content/football.mp4: 640x384 10 persons, 9.0ms
# video 1/1 (frame 6/843) /content/football.mp4: 640x384 10 persons, 11.0ms
# video 1/1 (frame 7/843) /content/football.mp4: 640x384 11 persons, 8.7ms
# video 1/1 (frame 8/843) /content/football.mp4: 640x384 11 persons, 8.8ms
# video 1/1 (frame 9/843) /content/football.mp4: 640x384 11 persons, 8.7ms
# video 1/1 (frame 10/843) /content/football.mp4: 640x384 10 persons, 8.8ms
# video 1/1 (frame 11/843) /content/football.mp4: 640x384 10 persons, 8.7ms
# ...

# %%
import glob
from IPython.display import Video

# This finds the most recent video file in the 'runs' folder
try:
    # Search for the video file
    video_files = glob.glob('runs/detect/track*/*.mp4')

    # Get the latest one
    latest_video = video_files[-1]

    print(f"Playing video: {latest_video}")
    # Embed the video player
    display(Video(latest_video, embed=True, width=600))

except IndexError:
    print("❌ No video found yet.")
    print("Make sure you ran the '!yolo track...' command and it finished successfully.")
# Out:
# ❌ No video found yet.
# Make sure you ran the '!yolo track...' command and it finished successfully.

# %%
# Train for 5 epochs to generate the "Research Graphs" for your report
# !yolo detect train model=yolov8n.pt data=coco8.yaml epochs=5 imgsz=640
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
